# %% [markdown]
# # Homework №14
# 1. Ознайомитися з датасетом зі списком автомобілів Automobile Data Set
# 2. Виділити і проаналізувати числові атрибути даної вибірки. Вивести дані про числові атрибути.
# 3. Виділити і проаналізувати категоріальні атрибути даної вибірки. Реалізувати конвертацію категоріальних атрибутів в бінарні.
# 4. Проаналізувати кількість відсутніх даних для кожного атрибута.
# 5. Описати проблеми з даними, які ви можете знайти для кожного атрибута
# 6. Зробити кореляцію для числових атрибутів. Знайти колінеарні атрибути (якщо такі є), описати їх і вказати, якими атрибутами можна знехтувати. Побудувати графіки кореляції для атрибутів. Видалити з датафрейма колінеарні атрибути.

# %% [markdown]
# підключаємо та налаштовуємо бібліотеки

# %%
import numpy as np

import pandas as pd
pd.set_option('display.max_columns', 60)

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(font_scale = 2)

pd.options.mode.chained_assignment = None

# %% [markdown]
# #### 1. Розглянемо датасет
# та загальні відомості про нього

# %%
dataFile = pd.read_csv('cars.csv')
dataFile[:20]
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
dataFile.info()
dataFile.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 205 non-null object
# stroke               205 non-null object
# ...

# %% [markdown]
# #### 2. Числові атрибути

# %% [markdown]
# Розглянемо числові атрибути

# %%
dataFile[:10].select_dtypes(include=['float64', 'int64'])
# Out:
#    symboling  wheel-base  length  width  height  curb-weight  engine-size  \
# 0          3        88.6   168.8   64.1    48.8         2548          130
# 1          3        88.6   168.8   64.1    48.8         2548          130
# 2          1        94.5   171.2   65.5    52.4         2823          152
# 3          2        99.8   176.6   66.2    54.3         2337          109
# 4          2        99.4   176.6   66.4    54.3         2824          136
# 5          2        99.8   177.3   66.3    53.1         2507          136
# 6          1       105.8   192.7   71.4    55.7         2844          136
# 7          1       105.8   192.7   71.4    55.7         2954          136
# 8          1       105.8   192.7   71.4    55.9         3086          131
# 9          0        99.5   178.2   67.9    52.0         3053          131
#
#    compression-ratio  city-mpg  highway-mpg
# 0                9.0        21           27
# 1                9.0        21           27
# ...

# %% [markdown]
# Атрибути типу object

# %%
dataFile[:10].select_dtypes(include=['object'])
# Out:
#   normalized-losses         make fuel-type aspiration num-of-doors  \
# 0                 ?  alfa-romero       gas        std          two
# 1                 ?  alfa-romero       gas        std          two
# 2                 ?  alfa-romero       gas        std          two
# 3               164         audi       gas        std         four
# 4               164         audi       gas        std         four
# 5                 ?         audi       gas        std          two
# 6               158         audi       gas        std         four
# 7                 ?         audi       gas        std         four
# 8               158         audi       gas      turbo         four
# 9                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location engine-type num-of-cylinders  \
# 0  convertible          rwd           front        dohc             four
# 1  convertible          rwd           front        dohc             four
# ...

# %% [markdown]
# Замінимо "?" на тип NaN

# %%
dataFile = dataFile.replace({'?': np.nan})
dataFile.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2               NaN         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1               NaN         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0               NaN         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# ...

# %% [markdown]
# Деякі дані типу object можна інтерпретувати до типу float

# %%
for col in list(dataFile.columns):
    # Select columns that should be numeric
    if ('normalized-losses' in col or 'bore' in col or 'stroke' in col or 'horsepower' in 
        col or 'peak-rpm' in col or 'price' in col):
        # Convert the data type to float
        dataFile[col] = dataFile[col].astype(float)

# %%
dataFile[:10].select_dtypes(include=['object'])
# Out:
#           make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
# 5         audi       gas        std          two        sedan          fwd
# 6         audi       gas        std         four        sedan          fwd
# 7         audi       gas        std         four        wagon          fwd
# 8         audi       gas      turbo         four        sedan          fwd
# 9         audi       gas      turbo          two    hatchback          4wd
#
#   engine-location engine-type num-of-cylinders fuel-system
# 0           front        dohc             four        mpfi
# ...

# %% [markdown]
# тепер набагато краще!

# %% [markdown]
# #### 3. Категоріальні атрибути
# З відомості про дані, бачимо, що такі колонки(normalized-losses, make, fuel-type, aspiration, num-of-doors і тд.) мают тип "object", тож потрібно провести конвертацію.
# Наприклад: aspiration має тільки два значення std і turbo, тому значення заміняємо на "0" і "1" відповідно(або ж для кожного значення свою колонку). body-style може набувати одного із 4+ значень, таким чином для для кожного створюємо власну колонку і ставимо "1" напроти певного автомобіля в тій колонкі, значення якої відповідає його типу.
#
# #### Коввертація в процесі )

# %%
dataFile = dataFile.replace({'one': 1,
                          'two': 2,
                          'three': 3,
                          'four': 4,
                          'five': 5,
                          'six': 6})
dataFile[['num-of-doors', 'num-of-cylinders']].head(10)
# Out:
#    num-of-doors num-of-cylinders
# 0           2.0                4
# 1           2.0                4
# 2           2.0                6
# 3           4.0                4
# 4           4.0                5
# 5           2.0                5
# 6           4.0                5
# 7           4.0                5
# 8           4.0                5
# 9           2.0                5

# %% [markdown]
# #### 4. Відсутні дані
# Перевіримо кількість відсутніх даних. Функцією взято з ресурсу Stack Overflow forum!

# %%
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

# %%
missing_values_table(dataFile)
# Out:
# Your selected dataframe has 26 columns.
# There are 7 columns that have missing values.
#                    Missing Values  % of Total Values
# normalized-losses              41               20.0
# bore                            4                2.0
# stroke                          4                2.0
# price                           4                2.0
# num-of-doors                    2                1.0
# horsepower                      2                1.0
# peak-rpm                        2                1.0

# %%
# dataFile.isin(['?']).any()

# %%
# print('normalized-losses', len(dataFile[dataFile['normalized-losses'] == '?']))
# print('num-of-doors', len(dataFile[dataFile['num-of-doors'] == '?']))
# print('bore', len(dataFile[dataFile['bore'] == '?']))
# print('stroke', len(dataFile[dataFile['stroke'] == '?']))
# print('horsepower', len(dataFile[dataFile['horsepower'] == '?']))
# print('peak-rpm', len(dataFile[dataFile['peak-rpm'] == '?']))
# print('price', len(dataFile[dataFile['price'] == '?']))

# %% [markdown]
# Враховуючи результати, бачимо, що стовпчик 'normalized-losses' має суттєві втрати значень в порівнянні з іншими стовпчиками. Але відсутні лише 20 відсотків, тож це не вплине на нашу модель.

# %% [markdown]
# #### 5. Проблеми
# 1. для полегшення роботи знак "?" можна замінити на значення NaN(вже виправлено!)
# 2. стовпчик normalized-losses має близько 20% невизначених даних
# 3. стовпчики num-of-doors, num-of-cylinders мають значення типу 'one', 'two', 'three', і тд. Краще замінити на числові значення типу int або float(вже виправлено!)

# %% [markdown]
# #### 6. Кореляція

# %%
dataFile.corr()
# Out:
#                    symboling  normalized-losses  num-of-doors  wheel-base  \
# symboling           1.000000           0.528667     -0.664550   -0.531954
# normalized-losses   0.528667           1.000000     -0.407134   -0.074362
# num-of-doors       -0.664550          -0.407134      1.000000    0.445696
# wheel-base         -0.531954          -0.074362      0.445696    1.000000
# length             -0.357612           0.023220      0.393593    0.874587
# width              -0.232919           0.105073      0.202072    0.795144
# height             -0.541038          -0.432335      0.547651    0.589435
# curb-weight        -0.227691           0.119893      0.195683    0.776386
# engine-size        -0.105790           0.167365      0.017519    0.569329
# bore               -0.134205          -0.036167      0.114501    0.490378
# stroke             -0.008965           0.065627     -0.010697    0.161477
# compression-ratio  -0.178515          -0.132654      0.165799    0.249786
# ...

# %% [markdown]
# З таблиці, ми можемо визначити силу звязку між атрибутами нашого дата сету, використавши шкалу Чедока.
#
# ![таблиця](https://iconfs.net/uploads/img/28.jpg "Шкала Чеддока")
#
# Атрибути є колінеарними, якщо коефіцієнт кореляції між ними > 0.7. Спираючись на це означення, можна поміркувати над видаленням атрибутів "width" і "curb-weight", тому що маю досить багато коеф. кор., які більше 0.7 у відношенні з іншими атрибутами.

# %% [markdown]
# #### Графіки скоро
